# %% [markdown]
# **Package imports**

# %%
# Set up our Notebook with required packages
import pandas as pd
import altair as alt

## Altair has a default limit of 5000 rows for rendering charts (if our dataframe has more than this, we'll get an error when making the chart).
##  To override this limit, we can set the max_rows option.
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# # CC8: the Long-Run Prices Dataset
#
# A notebook using the LRPD, described [here](https://cep.lse.ac.uk/pubs/download/occasional/op055.pdf).
#
# </br></br></br></br>

# %% [markdown]
# **What is our goal?**
#
# - Take a large dataset, extract and aggregate down to a level of data we can visualise.
#
# Example workflow:
# 1. Load `prices` and `items` datasets (item description is separated from prices observations to reduce the size of the data files, we use a numerical `item_id` to match between them.)
# 2. Search the `items` dataset to find an item (or multiple items) that we want to analyse, record the `item_id` value(s).
# 3. Take the `item_id` value(s) and filter the `prices` dataframe

# %% [markdown]
# <br>
#
# ### Step 1. Loading data
#
# #### 1a. Load prices dataset
#
# Note: the file linked to the cloud storage here is the same `db_prices` file available in the DropBox and linked in the lecture slides. Don't worry about the different `.parquet` file type here - it's just another file type like CSV & JSON, and works well with large datasets. The only change is to use `pd.read_parquet()` instead of `read_csv()` - the loaded dataframe is the same.

# %%
prices_df = pd.read_parquet('https://autocpi-public.s3.eu-west-2.amazonaws.com/lrpd/db_prices.parquet')

# What columns do we have?
print(prices_df.columns, "\n")

# Get summary statistics and round the results for better readability
prices_df.describe().round()
# Out:
# Index(['quote_date', 'shop_code', 'item_id_raw', 'region', 'price',
#        'indicator_box', 'item_id'],
#       dtype='object')
#        quote_date   shop_code  item_id_raw      region       price     item_id
# count  48368958.0  48368958.0   48368973.0  48368958.0  48368958.0  48368973.0
# mean     200776.0       477.0     388041.0         7.0        50.0    388398.0
# std        1060.0      1532.0     146756.0         3.0       206.0    146672.0
# min      198802.0         1.0     210101.0         1.0         0.0    210101.0
# 25%      199811.0        39.0     212917.0         3.0         1.0    212918.0
# 50%      200805.0        88.0     430128.0         7.0         5.0    430132.0
# 75%      201707.0       802.0     510406.0         9.0        20.0    510407.0
# max      202510.0     20071.0     640406.0        13.0     44000.0    640406.0

# %% [markdown]
# View the dataframe

# %%
# Print 5 random rows from the dataframe
prices_df.sample(5)
# Out:
#           quote_date  shop_code  item_id_raw  region      price indicator_box  \
# 44809456    200501.0      915.0       630105     8.0  79.989998
# 25013371    199607.0      179.0       430214     3.0   3.200000             S
# 18743535    200508.0       85.0       310307     7.0   1.250000
# 30678013    200404.0       96.0       440233    13.0   5.000000
# 32759352    199608.0      115.0       510208     8.0  44.990002
#
#           item_id
# 44809456   630105
# 25013371   430214
# 18743535   310307
# 30678013   440233
# 32759352   510208

# %% [markdown]
# To make visalising the data easier later, we can convert the `quote_date` column into the standard format.
# > We give the function the current date format, so 202510 is YYYYMM, which corresponds to `%Y%m` in date notation (`%Y`=YYYY, `%m`=MM). The notation is the same as formatting dates in Vega-Lite, and uses [D3 time formats](https://d3js.org/d3-time-format).

# %%
# Using pandas `to_datetime` function to convert 'quote_date' column to datetime format
prices_df['date'] = pd.to_datetime(prices_df['quote_date'], format='%Y%m')
prices_df.head(1)
# Out:
#    quote_date  shop_code  item_id_raw  region  price indicator_box  item_id  \
# 0    200102.0      808.0       210101    12.0   0.35             Q   210101
#
#         date
# 0 2001-02-01

# %% [markdown]
# <br>
# <br>
# <br>
#
# #### **1b.** Load items data

# %%
items_df = pd.read_parquet('https://autocpi-public.s3.eu-west-2.amazonaws.com/lrpd/db_item.parquet')

# Print the number of rows (i.e. products)
print(f"Number of rows in items_df: {len(items_df):,} \n")

items_df.head()
# Out:
# Number of rows in items_df: 1,387
#    item_id                     description  date_quote_s  date_quote_e  n_obs
# 0   210101    LARGE LOAF-WHITE-SLICED-800G        198802        200401  36039
# 1   210102  LARGE LOAF-WHITE-UNSLICED-800G        198802        202510  56917
# 2   210105   LARGE WHOLEMEAL LOAF-UNSLICED        198802        200301  27161
# 3   210106     SIX BREAD ROLLS-WHITE/BROWN        198802        202510  67469
# 4   210107     BROWN LOAF,400G,SLICED-GRAN        198903        200401  29361

# %% [markdown]
# The items data contains a description for each `item_id`, along with information on number of price observations, the earliest and last date that product has a price record.
#
# There are 1,387 (as of Nov 2025) unique items in the long-run price dataset (keeping this out of the main prices dataset avoids unneccesarily duplicating this information for every price observation).

# %% [markdown]
# > NOTE: Statistical agencies update the basket of goods used to sample inflation as consumer spending habits change over time - often the result of technological change. This is why not all items have data up to today.
#
# **Optional** Filter to only 'current' items, i.e. their latest observation matches

# %%
# Filter items_df to only include rows where 'date_quote_e' is equal to the maximum value of 'date_quote_e'
# (By searching for the max, we don't need to hard-code a date, which may become outdated over time)
items_df_current = items_df[items_df['date_quote_e'] == items_df['date_quote_e'].max()].copy()
# same as items_df[items_df['date_quote_e'] == 202510]

print(f"Number of current items: {len(items_df_current):,} \n")
items_df_current.head()
# Out:
# Number of current items: 584
#     item_id                     description  date_quote_s  date_quote_e  n_obs
# 1    210102  LARGE LOAF-WHITE-UNSLICED-800G        198802        202510  56917
# 3    210106     SIX BREAD ROLLS-WHITE/BROWN        198802        202510  67469
# 8    210111  WHITE SLICED LOAF BRANDED 750G        200402        202510  36848
# 10   210113   WHOLEMEAL SLICED LOAF BRANDED        200402        202510  35696
# 11   210114            CHILLED GARLIC BREAD        201002        202510  41672

# %% [markdown]
# <br>
#
# #### **1c.** Searching for a product
#
# Look in the items data for some products we're interested in.

# %%
# Print unique values in the 'description' column
items_df_current['description'].unique()
# Out:
# array(['LARGE LOAF-WHITE-UNSLICED-800G', 'SIX BREAD ROLLS-WHITE/BROWN',
#        'WHITE SLICED LOAF BRANDED 750G', 'WHOLEMEAL SLICED LOAF BRANDED',
#        'CHILLED GARLIC BREAD', 'WRAP / TORTILLA PACK 6-8',
#        'GLUTEN FREE BREAD LF 300-550G', 'FLOUR-SELF-RAISING-1.5KG',
#        'DRY SPAGHETTI OR PASTA 500G', 'CORN SNACK SINGLE PACK MAX 50G',
#        'BASMATI RICE 500G-1KG', 'BREAKFAST CEREAL 1',
#        'BREAKFAST CEREAL 2', 'CEREAL BAR', 'HOT OAT CEREAL',
#        'RICE MICRO POUCH/TRAY 220-280G', 'BREAKFAST CEREAL GLUTEN FREE',
#        'COUSCOUS PLAIN/FLAVOURED', 'RICE CAKES PACK 100-180G',
#        'CREAM CRACKERS PACK 200G-300G', 'PLAIN BISCUITS-200-300G',
#        'WHOLE SPONGE CAKE NOT FROZEN', 'PACK OF 5-6 INDIVIDUAL CAKES',
#        'BISCUITS HALF CHOC 260-400G', 'CRUMPETS PACK 6-9 SPEC NUMBER',
#        'HOME KILLED BEEF-LEAN MINCE KG', 'HOME KLD BEEF-RUMP/POPES STEAK',
#        'FROZEN BEEFBURGERS PACK OF 4', 'BEEF ROASTING JOINT PER KG',
#        'HK LAMB LOIN CHOP/STEAK PER KG', 'HOME KILLED PORK CHOP/STEAK',
#        'BACON-GAMMON-PER KG', 'BACON-BACK-PER KG',
#        'FRESH/CHILLED CHICKEN  PER KG', 'FRESH BONELESS CHICKEN BREAST',
#        'CANNED MEAT-STEWED STEAK', 'INDIVIDUAL MEAT PIE',
#        'SAUSAGES-PORK-PER KG', 'FROZ CHICKEN NUGGETS 220-600G',
#        'COOKED HAM PREPACKED SLICED', 'CONTINENTAL SLICED DELI MEAT',
#        'CHICKEN KIEV 2 PACK 240-325G', 'H K LIVER PER KG STATE TYPE',
#        'COOKED MEAT TURKEY/CHICK SLICE', 'MEAT BASED SNACK PACK MAX 400G',
#        'FRESH WHITE FISH FILLETS KG', 'FRESH FISH-SALMON FILLETS-KG',
#        'FROZEN PRAWNS PER KG', 'CANNED FISH, TUNA, 130G-200G',
#        'FROZEN FISH FINGERS 8-12 PK', 'FROZEN BREAD/BAT FISH 400-550G',
#        'SPREADABLE BUTTER', 'BUTTER 250G SPEC COO',
#        'OLIVE OIL - 500ML - 1 LITRE', 'PEANUT BUTTER, JAR, 225-350G',
#        'DAIRY SPREAD/MARGARINE', 'DAIRY FREE SPREAD/MARGARINE',
#        'SPRAY OIL BOTTLE 190-220MLS', 'CHEDDAR-HOME PRODUCED PER KG',
#        'CHEESE SPREAD, 125g-200g TUB', 'HARD REGIONAL CHEESE PER KG',
#        'PARMESAN CHEESE-PER KG', 'SOFT CONTINENTAL CHEESE - KG',
#        'EGGS PER DOZEN OR 2 X 6 BOX', 'SHOP MILK-WHOLE MILK-4PT/2LTR',
#        'MILK SEMI-PER 2 PINTS/1.136 L', 'MILK FLAVOURED, 180-500MLS/GMS',
#        'NON-DAIRY MILK DRINK 900ML-1LT', 'YOGHURT/FROMAGE 4-6PK, 45-125G',
#        'CHILLED POT DESSERT 125-200G', 'YOGHURT-SMALL INDIVIDUAL',
#        'FRESH DOUBLE CREAM 250ML-300ML', 'POWDERED BABY FORMULA 400-900G',
#        'TEA BAGS PKT OF 80 (230G-250G)', 'TEA BAGS-2-PACKET OF 240',
#        'FLAVRD TEA 15-20 BAGS, 30-40G', 'FRUIT SQUASH, 750ML - 1.5LT',
#        'FRUIT JUICE NOT ORANGE 1L', 'LEMONADE-2 LITRE BOTTLE',
#        'MINERAL WATER STILL 1.5-2L', 'FIZZY ENERGY DRINK 250-500ML',
#        'FRESH/CHILL ORANGE JUICE 900ML', 'FIZZY BOTTLED DRINK 500ML',
#        'FRUIT DRINK BOTTLE 4-8 PACK', 'BOTTLE STILL WATER 500ML',
#        'MIXER DRINK BOTTLE 1L EG TONIC', 'COLA/FIZZY DRINK 330ML PK 4-8',
#        'FLAVOURED WATER BOTT 900ML-1.5', 'COLA DRINK, REG,BOTTLE,1.25-2L',
#        'COLA DRINK, DIET 1.25-2LTR', 'FRUIT/VEG SMOOTHIE',
#        'SUGAR -GRANULATED-WHITE-PER KG', 'JAR OF JAM-340-454G',
#        'HONEY JAR/BOTTLE 340G-454G', 'MINTS', 'CHOCOLATE 4',
#        'CHEWING/BUBBLE GUM-SINGLE PK', 'CHOCOLATE 10',
#        'CHOCOLATE LARGE BAR 100-200G', 'CHOCOLATE 12',
#        'POTATOES-NEW-PER KG', 'POTATOES- OLD WHITE PER KG',
#        'POTATOES- BAKING PR KG', 'POTATO CRISPS 25G-50G',
#        'POTATO CRISPS-MULTI-PACK', 'FROZEN CHIPS 900G-1.5KG',
#        'PREMIUM POTATO CRISPS/CHIPS', "P'PARED MASHED POTATO 400-650G",
#        'FRESH VEG-CAULIFLOWER-EACH', 'FRESH VEG-CUCUMBER-WHOLE',
#        'FRESH VEG-LETTUCE-ICEBERG-EACH', 'FRESH VEG-TOMATOES-PER KG',
#        'FRESH VEG-CABBAGE-WHOLE-PER KG', 'FRESH VEG-CARROTS-PER KG',
#        'FRESH VEG-ONIONS-PER KG', 'FRESH VEG-MUSHROOMS-PER KG',
#        'FRESH VEG-BROCCOLI-PER KG', 'FRESH VEG-COURGETTE-PER KG',
#        'FRESH VEG-PEPPERS -LOOSE OR KG', 'VEGETABLE STIR FRY FRESH PACK',
#        'SWEET POTATO PER KG OR EACH', 'GREEN BEANS PER KG OR PACK',
#        'PREPACKED SALAD 75 - 250G', 'CANNED TOMATOES 390-400G',
#        'BAKED BEANS, 400-425G TIN', 'CANNED SWEETCORN 198-340G',
#        'FROZEN GARDEN PEAS 800G-1KG', 'FROZEN PRE-PREPARED VEGTABLES',
#        'PULSES CAN 390 - 420G', 'ORANGES-CLASS 1-EACH',
#        'AVOCADO PEAR-EACH', 'KIWI FRUIT-EACH', 'GRAPEFRUIT-EACH',
#        'APPLES-DESSERT-PER KG', 'PEARS-DESSERT-PER KG', 'BANANAS-PER KG',
#        'STRAWBERRIES PER KG OR PUNNET', 'GRAPES-PER KG',
#        'SMALL TYPE ORANGES PER PACK/KG', 'PLUMS PER KG/PACK',
#        'FRUIT FRESH SNACKING 150-350G', 'LEMON EACH',
#        'BLUEBERRIES PUNNET OR PER KG', 'RASPBERRIES PUNNET OR PER KG',
#        'APPLES DESSERT EACH', 'MELON EACH EG HONEYDEW', 'PINEAPPLE EACH',
#        'PACKET OF PEANUTS 150-300G', 'CANNED FRUIT-400-450G',
#        'DRIED FRUIT - EG APRICOTS', 'BERRIES FROZEN PACK',
#        'VEGETABLE PICKLE 280-520G', 'CANNED SOUP-390-425G',
#        'TOMATO KETCHUP BOTTLE 340-570G', 'FRZN READY-COOKD MEAL SERVES 1',
#        'COOK-IN SAUCE-JAR/CAN 350-520G', 'FROZ VEG BURGER/GRILL 180-454G',
#        'MAYONNAISE 390-500G/420-540MLS', 'ICE CREAM 450ML-1L',
#        'DRIED POTTED SNACK 50-120G', 'CHILLED READY MEAL-MEAT-SERVS1',
#        'CHILLED READY MEAL-FISH/VEG', 'CHOCOLATE COVERED ICE CREAM',
#        'CHILLED PIZZA EACH 300-600G', 'PROTEIN POWDER 900G-2KG',
#        'QUICHE 340G-450G', 'VEGETABLE CRISPS PACK 80-125G',
#        'YORKSHIRE PUDDING FROZEN', 'SAUSAGE MEAT FREE CHILLED PACK',
#        'HERBS DRIED JAR 3 - 20G', 'SUNFLOW/PUMPK SDS PK 100-300G',
#        'COFFEE-INSTANT 90 -100G JAR', 'HOT CHOCOLATE DRINK INSTANT',
#        'COFFEE PODS PACK 8-16', 'COFFEE SACHETS PACK', 'PUB -HOT MEAL',
#        'BOTTLED MINERAL WATER', 'RESTAURANT CUP OF COFFEE',
#        'RESTAURANT - SWEET COURSE', 'MUFFIN/INDIVIDUAL CAKE',
#        'FRUIT JUICE BOTTLE 250-350ML', 'RESTAURANT MAIN COURSE',
#        'STAFF RESTAURNT HOT SNACK ITEM', 'PRIMARY SCHOOL- FIXED CHARGE',
#        'SECONDARY SCHOOL- CAFETERIA', 'STAFF RESTAURANT MAIN COURSE',
#        'FISH & CHIPS TAKEAWAY', 'SANDWICH-TAKE-AWAY (COLD)',
#        'POTATO CRISPS-INDIVIDUAL PACK', 'PIZZA TAKEAWAY OR DELIVERED',
#        'INDIAN TAKEAWAY', 'CHINESE TAKEAWAY', 'TAKEAWAY SOFT DRINK',
#        'KEBAB- TAKEAWAY', 'CINEMA POPCORN', 'TAKEAWAY CHICKEN & CHIPS',
#        "T'AWAY COOKED SAVOURY PASTRY", 'BURGER IN A BUN EAT IN OR TAKE',
#        'HOT DRINK TAKE AWAY SPECIFY TY', 'DRAUGHT BITTER (PER PINT)',
#        'LAGER - PINT 3.4-4.2%', 'PREMIUM LAGER - PINT 4.3-7.5%',
#        'BOTTLED PREMIUM LAGER 4.3-7.5%', 'CIDER 4.5%-5.5% ABV PINT/BOTTL',
#        'BITTER-4CANS-440-500ML', 'LAGER 4 BOTTLES- PREMIUM',
#        'LAGER 10 - 24 CANS (440-500ML)', 'LAGER 10-24 BOTTLES 250-330ML',
#        'STOUT - 4 CAN PACK', "SPEC'Y BEER BOTT 500ML 4-5.5",
#        'APPLE CIDER 4 CAN PK 440-500ML', 'CIDER FLAVOURED BOTT 500-568ML',
#        'WHISKY (PER NIP) SPECIFY ML', 'VODKA (PER NIP) SPECIFY ML',
#        'BOTTLE OF MIXER 125-200ML', 'LIQUEUR PER NIP   SPECIFY ML',
#        'WINE, PER 175 - 250 ML SERVING', 'LEMONADE/COLA DRAUGHT',
#        'BOTTLE OF WINE 70-75CL', 'GIN PER NIP', 'WHISKY-70 CL BOTTLE',
#        'VODKA-70 CL BOTTLE', 'BRANDY 70CL BOTTLE',
#        'FORTIFIED WINE  (70-75CL)', 'WHITE WINE- EUROPEAN 75CL',
#        'WHITE WINE- NEW WORLD 75CL', 'BOTTLE OF CHAMPAGNE 75 CL',
#        'ROSE WINE-75CL BOTTLE', 'SPARKLING WINE 75CL MIN 11%ABV',
#        'RUM WHITE EG BACARDI 70CL BOTT', 'CREAM LIQUER 70CL-1LT 14-20%',
#        'GIN BOTTLE 70CL', 'PRE MIXED SPIRIT 250-330ML',
#        'RED WINE 75CL BOTTLE', 'CIGARETTES 8', 'CIGARETTES 15',
#        '20 FILTER - OTHER BRAND', 'E-CIG REFILL BOTTL/CART 2-10ML',
#        '5 CIGARS: SPECIFY BRAND', 'HAND ROLLING TOBACCO PACK 30GM',
#        'PLUMBER-DAYTIME HOURLY RATE', 'ELECTRICIAN-DAYTIME RATE/HOUR',
#        'DECORATOR-DAILY RATE;SPEC HRS', 'CARPENTER HOURLY RATE',
#        'READY-MIXED FILLER-INT USE', 'PAINT BRUSH-2INCH/5CM WIDTH',
#        'DOOR HANDLE-PACK FOR ONE DOOR', 'POWER DRILL-HAMMER ACTION',
#        'VARNISH-CLEAR GLOSS-750ML-1LTR', 'SCREWDRIVER', 'SHOWER HEAD',
#        'HIRE OF DOMES CARPET CLEANER', 'MDF',
#        'CERAMI TILES 15X15-25X50CM BOX', 'WOODSCREWS STEEL/ZIN PLATED PK',
#        'PAINT GLOSS/EMUL 750ML-2.5LTR', 'SMOKELESS FUEL 50KG',
#        'KEROSENE - 1000L DELIVERED', 'DOUBLE WARDROBE',
#        'ARMCHAIR -UPHOLSTERED', 'KITCH BASE UNIT WIDTH 800-1000',
#        'COFFEE TABLE', 'CHEST OF DRAWERS', 'MATTRESS- 3FT/90CM',
#        'BOOKCASE/FREESTAND SHELV UNIT', 'LEATHER SETTEE',
#        'HOME OFFICE DESK', 'KITCH WALL UNIT WIDTH 800-1000',
#        'DINING TABLE & 2-6 CHAIRS', 'HIGH CHAIR',
#        'SETTEE,NON LEATHER - SEE HELP', 'BED ADULT SPECIFY SIZE',
#        'DUVET-DOUBLE TOG 10-13.5', 'DUVET COVER', 'FITTED BED SHEET',
#        'BATH SHEET', 'FABRIC ROLLER BLIND 120-180CM',
#        'CARPET TUFTED 100% MANMADE FIB', 'CARPET TUFTED MIN 80% WOOL FIB',
#        'FLOOR RUG STATE SIZE & MATERIA', "CURTAINS READY MADE SP'FY SIZE",
#        'LUXURY VINYL TILE PER SQ M', 'ELECTRIC COOKER',
#        'ELECTRIC KETTLE - 1.5-1.7L', 'ELECTRIC IRON', 'ELECTRIC RAZOR',
#        'TABLE LAMP', 'PHONE NT MOBILE(SPEC DIG/ANAL)',
#        'ELECTRIC HAIR STYLING APP', 'VACUUM CLEANER',
#        'DISH WASHER 12-15 PLACE SET', 'ELECTRIC HEATER -SEASONAL',
#        'WASHING MACH NO DRYER MAX 1800', 'FRIDGE/FREEZER SPEC CAPACITIES',
#        'ELECTRIC TOOTHBRUSH', 'SECURITY / SURVEILLANCE CAMERA',
#        'AIR FRYER SPECIFY CAPACITY', 'SMALL SAUCEPAN,MILK',
#        'SCISSORS - HOUSEHOLD', 'GAS FIRE',
#        'GAS COOKERS-SPECIFY MAKE & MOD', 'PLASTIC FOOD STORAGE CONTAINER',
#        'STAINLESS STEEL CUTLERY SET', 'PLAIN GLASS TUMBLER',
#        'FRYING PAN 24-30CM', 'DINNER PLATE, APPROX DIAMETER',
#        'BALL POINT', 'ALUMIN COOKING FOIL 290-300MM',
#        'WASHING UP LIQUID 380-900ML', 'HOUSEHOLD CLEANER CREAM/LIQUID',
#        'LIGHT BULB', 'CLEAR STICKY TAPE', 'GREETINGS CARD; STATE CODE',
#        'A4 PRINTER PAPER (500 REAM)', 'BLEACH 750ML',
#        'BLACK INKJET CARTRIDGE', 'FABRIC CONDITIONER 500ML-1.5LT',
#        'KITCHEN ROLL PK OF 2-4 SPECIFY', 'SHEET OF WRAPPING PAPER',
#        'TOILET ROLLS', 'DISHWASHER TABLETS PACK 16-45',
#        'DRYCELL BATTERY 4 PACK EG AA', 'WASHING LIQUID 800ML/1.5LTR',
#        'LIGHT BULB SMART/WIFI', 'SURFACE WIPES ANTIBACTERIAL',
#        'BIN LINERS KITCHEN USE', 'DOG FOOD-CAN-385-400GM',
#        'ANIMAL CAGE (E.G FOR GERBIL)', 'ANNUAL BOOSTER INJECTION',
#        'DOG KENNEL FEES DAILY CHARGE', 'SMALL CAGED MAMMAL',
#        'CAT FOOD POUCH-IND-85G-100G', 'DOG TREATS,SPEC,TYPE 70-400G',
#        'PET COLLAR DOG / CAT', 'WILD BIRD SEED PACK 900G -3.5K',
#        'DOMESTIC CLEANER HOURLY RATE', "DRY CLEANING-MAN'S SUIT",
#        'DRIVING LESSON 1 HOUR', 'WINDOW-CLEAN 3-BED SEMI',
#        'WASHING MACHINE REPAIR', 'PC REPAIR',
#        'CHILD MINDER - HOURLY RATE', 'EVENT CATERING, SET MENU, COST',
#        'HOME REMOVAL- 1 VAN', 'WEEKLY NANNY FEES',
#        'MONTHLY SELF STORAGE FEE', 'HOME CARE ASSISTANT HRLY RATE',
#        'PLAYGROUP FEES - PER SESSION', 'WATCH BATTERY REPLACEMENT',
#        "MEN'S CLOTHING HIRE- SEE HELP", 'HOME-BUYERS SURVEY-RSDNTL PPTY',
#        'FUNERAL-CREMATION', 'NURSERY FEES: CHILD 0-4',
#        'BASIC WILL FOR A SINGLE PERSON', 'HOUSE CONVEYANCING',
#        'HOURLY RATE FOR SOLICITOR', 'MENS JACKET/COAT', 'MENS JEANS',
#        "MEN'S JUMPER-KNITTED", "MEN'S FORMAL SHIRT-LONG SLEEVE",
#        'MENS CASUAL S/SLEEVE TOP', "MEN'S FORMAL RDY-MADE TROUSERS",
#        "MEN'S CASUAL TROUSERS", "MEN'S JUMPER OR SWEATSHIRT",
#        "MEN'S TRACKSUIT/JOGGIN BOTTOMS", 'MENS BRANDED T-SHIRT',
#        'MENS OFFICIAL FOOTBALL SHIRT', "MEN'S BRANDED SPORT SWEATSHIRT",
#        'MENS 3/4 TO FULL LENGTH COAT', 'MENS CASUAL SHIRT',
#        "MEN'S T-SHIRT SHORT SLEEVED", 'MENS LOUNGEWEAR BOTTOMS',
#        'MENS FORMAL JACKET/BLAZER', 'WOMENS BLOUSE/SHIRT 1',
#        "WOMEN'S FORMAL JACKET", "WOMEN'S JUMPER",
#        'WOMENS BASIC PLAIN T-SHIRT', "WOMEN'S CASUAL OUTER JACKET",
#        "WOMEN'S LONG SLV TOP-NT BLOUSE", "WOMEN'S CARDIGAN",
#        "WOMEN'S TROUSERS-CASUAL", "WOMEN'S TROUSERS-FORMAL",
#        "WOMEN'S SKIRT: CASUAL", "WOMEN'S SKIRT: WORK/FORMAL",
#        "WOMEN'S VEST/STRAPPY TOP", 'WOMENS DRESS -CASUAL/FORMAL',
#        'WOMENS SHORT SLEEVE SPORTS TOP', "WOMEN'S JEANS- OWN BRAND",
#        "WOMEN'S JEANS- BRANDED", "WOMEN'S COAT - SEE HELP SCREEN",
#        'WOMENS SPORTSWEAR SHORTS', "WOMEN'S SHOWERPROOF JACKET",
#        'WOMENS BLOUSE / SHIRT 2', 'WOMENS LEGGINGS FULL LENGTH',
#        'WOMENS SHORT SLEEVE FORMAL TOP', 'WOMENS EXERCISE LEGGINGS',
#        "WOMEN'S SWEATSHIRT", 'TROUSERS  FOR SCHOOL 5-13 YRS',
#        'BOYS JEANS (5-13 YEARS)', 'BABY SLEEPSUIT LONG SLEEVE',
#        'GIRLS SKIRT FOR SCHOOL 5-13YRS', 'GIRLS FASHION TOP 12-13 YEARS',
#        'GIRLS TROUSERS NOT DENIM 5-13', 'GIRLS JACKET (5-13 YEARS)',
#        'BOYS T-SHIRT 3-13 YEARS', 'GIRLS LEGGINGS 5-13 YEARS',
#        "BOY'S JUMPER/SWTSHRT/CARDIGAN", "INFANT'S TROUSERS 0-2 YEARS",
#        "INFANT'S JUMPR/SWTSHRT/CARDIGN", 'DRESS 0 - 2 YEARS',
#        "MEN'S PANTS/BOXER SHORTS", "WOMEN'S NIGHTDRESS/PYJAMAS",
#        "WOMEN'S PANTS", 'BRA, CUP SIZE A-D RANGE', "WOMEN'S SWIMWEAR",
#        'MENS SOCKS 1 PAIR', "WOMEN'S TIGHTS", "MEN'S TIE",
#        'KNITTING WOOL-DOUBLE KNIT-100G', "LADY'S SCARF",
#        'MENS BASE LAYER TOP LONG/SHORT', 'HAT/CAP, ADULT',
#        'SPORTS BRA / CROP TOP', 'CHILDS PYJAMAS 3 - 13 YRS',
#        'CHILDS PANTS ONE PAIR 3 - 13', 'CHILDS SOCKS ONE PAIR UK9',
#        'MENS BELT', 'WOMENS SOCK 1 PAIR', 'MENS SHOE FORMAL STYLE',
#        "WOMEN'S SANDALS", "BOY'S SHOES", "GIRL'S SHOES SCHOOL",
#        "MEN'S SHOE CASUAL STYLE", "MEN'S TRAINING SHOE-SPORTSWEAR",
#        "WOMEN'S TRAINING SHOES", "CHILD'S TRAINERS-SPORTS",
#        'WOMANS BOOTS', 'WOMEN\'S SHOES-FLAT MAX 1" HEEL', 'WOMENS SHOE',
#        "LADY'S UMBRELLA -FOLDING", 'LADIES HAND/SHLDER BAG',
#        'FLOWER VASE', 'EARRINGS- FASHION', 'SOLID GOLD RING 9CT',
#        "GENT'S WATCH- ANALOGUE FACE", 'WALL HANGING MIRROR UPTO 1.5SQ',
#        'LUGGAGE TROLLEY CASE - 60-70CM', 'DIAMOND SOLITAIRE RING',
#        'PHOTO FRAME', 'STERLING SILVER EARRINGS',
#        'SPECTACLE FRAMES WITH LENSE', 'DAILY DISPOSABLE SOFT LENSES',
#        'NECKLACE FASHION APX 16/20 INS', 'MOBILE PHONE ACCESSORY',
#        'RE-USABLE BOTTLE/MUG ADULT', 'INDIGESTION TABLETS 16-24 PACK',
#        'TOOTHPASTE (SPECIFY SIZE)', 'TISSUES-LARGE SIZE BOX',
#        'MOISTURISER FACIAL 50-150ML', 'DEODORANT/ANTI PERSPI 50-250ML',
#        'DISP NAPPIES, SPEC TYPE, 20-60', 'MULTI-VITAMINS CAPSULES/TABLET',
#        'MASCARA', 'SHAMPOO-250-400ML', 'PAIN KILLER TABLETS-16-24 PACK',
#        'PLASTERS-20-40 PACK', 'CONDOMS PACK OF 3-14',
#        'PERFUME/FRAGRANCE MEN OR WOMEN', 'SUNSCREEN - SPEC SIZE/SPF',
#        'WOMENS HAIR COLOURANT 60-140ML', 'HAIR GEL 150-200ML',
#        'SHOWER GEL 150-250ML', 'RAZOR CARTRIDGE BLADES',
#        'COLD/FLU DRINK POWDER', 'LIQUID FOUNDATION 30-35ML', 'TOOTHBRUSH',
#        'ANTIHISTAMINE ALLERGY TABLETS', 'LIP GLOSS',
#        'LIQUID SOAP 200-300ML', 'CONDITIONER FOR HAIR',
#        'BABY WIPES 50-85', 'NAIL VARNISH BOTTLE 6 - 14mls',
#        'COUGH LIQUID BOTTLE 150-200MLS', "BODY M'RISING LOTION 200-400ML",
#        'SELF TANNING PRODUCT', 'MOUTHWASH BOTTLE 300-600MLS',
#        'SANITARY TOWELS PACK 10-20', "MAN'S HAIRCUT",
#        "WOMEN'S HRDRESSING-CUT/BLOWDRY", 'WOMENS HIGHLIGHTING',
#        'NON-NHS MEDICINE-PHYSIOTHERAPY', 'RESIDENTIAL HOME',
#        'NURSING HOME', 'PRIVATE DENTAL EXAMINATION', 'BASIC MANICURE',
#        'NON NHS CHIROPRACTOR', 'E BIKE ADULT SPEC GEARS AND WA',
#        'CAR TYRE, STATE SIZE', 'WINDSCREEN WIPER BLADES',
#        'CAR MOT TEST FEE, VAT EXEMPT', 'CAR SERVICE- LOCAL GARAGE',
#        'CAR SERVICE- MAIN DEALER', 'CAR REPAIRS MAIN DEALER',
#        'CAR REPAIRS LOCAL GARAGE', 'CAR BULB 12 VOLT SPECIFY WATTS',
#        'CAR WASH HAND OR AUTOMATIC', 'WHEEL ALIGNMENT',
#        'EXHAUST FITTING FAST FIT', 'OIL PER LITRE-MULTIGRADE',
#        'SELF-DRIVE VAN HIRE', 'PUSHCHAIR/STROLLER',
#        'SELF-DRIVE CAR HIRE BASIC 24HR', 'MINICAB FARE FOR 2 MILES',
#        'CAR PARK CHARGES', 'CHILDS BICYCLE', 'ADULT BIKE',
#        'CYCLE HELMET 12+ SPEC ROAD/MOU', 'CAR SEAT TODDLER/CHILD',
#        'DIGITAL RADIO (DAB)', 'HEADPHONES/EARPHO SPECIFY TYPE',
#        'TELEVISION 39" OR SMALLER', 'TELEVISION 40" OR LARGER',
#        'PORTABLE SPEAKER', 'DVD/BLU RAY PLAYER',
#        'PORTABLE DIGITAL MUSIC PLAYER', 'SOUNDBAR', 'PRINTER',
#        'RECORDABLE CD PRICE PER CD', 'PRE-RECORDED DVD (FILM)',
#        'CD ALBUM (TOP 40)', 'BLU RAY DISC (FILM) FROM CHART',
#        'BOXED BOARD GAME: NOT TRAVEL', "CHILD'S PLASTIC DOLL",
#        'MODEL RD VEHICLE EG HOT WHEELS', 'CONSTRUCTION TOY: SPEC KIT NO',
#        'SLEEPING BAG, ADULT', "CHILD'S SOFT TOY/TEDDY BEAR", 'FOOTBALL',
#        'CARBON FIBRE FISHING ROD', 'PRESCHOOL ACTIVITY TOY',
#        "BEGINNER'S ACOUSTIC GUITAR", "MEN'S FOOTBALL BOOTS",
#        'GOLF BALLS PRICE PER BALL', "CHILD'S BABY DOLL",
#        'SQUASH/TENNIS RACQUET', 'DIGITAL DEVELOPMENT PER PRINT',
#        'CRAFT KIT FOR CHILD 5 YRS+', 'ELECTRONIC EDUCATIONAL TOY',
#        'JIGSAW MINIMUM 100 PIECES', 'CHILDS SCOOTER AGE 5-12 YEARS',
#        "CHILDS SIT & RIDE TOY U'ER 5'S", 'ACTION CAMERA',
#        'COMPUTER GAME 1', 'COMPUTER GAME 2', 'COMPUTER GAME 3',
#        'HAND WEIGHTS FOR HOME EXERCISE', 'CRAFT HOBBY KIT ADULT',
#        'COMPUTER GAME ACCESSORY', 'SD CARD SINGLE', 'USB STICK EACH',
#        'CARD GAME', '', 'BOOK-NON-FICTION-HARD-COVER',
#        'BOOK-NON-FICTION-PAPER-BACK', 'BOOK ILLUSTRATED FOR UNDER 5',
#        'BOOK - FICTION - HARD COVER', 'BOOK - TEENAGE FICTION',
#        'BOOK FICTION P/BACK TOP 10', 'CHILDS BOOK, FICTION 6-12YRS',
#        'GARDEN SPADE', 'HOUSEPLANT', 'POTTING COMPOST',
#        'CUT FLOWERS-CARNATIONS-STEM', 'POTTED SHRUB',
#        'PLANT FOOD 800ML-2LT/500G-1.5K', 'THEATRE ADULT EVES-FRONT STLLS',
#        'SWIMMING POOL ADM STND ADULT', 'EXERCISE CLASS UPTO 1HR',
#        'TEN-PIN BOWLING PER GAME', 'PRIVATE HEALTH CLUB ANNUAL FEE',
#        'LIVERY CHARGES PER WEEK', 'SOFT PLAY SESSION TIME PERIOD',
#        'CLIMBING WALL SESSION', 'HOTEL 1 NIGHT PRICE'], dtype=object)

# %% [markdown]
# <br>
#
# ### Step 2. Aggregating
#
# Before plotting, we need to filter aggregate the data.
#
# #### 2a. Filter prices on `item_id`.
#
#
# <br>
#
# How do we filter?
# `df[df['columnx'] == 'xyz']`:
# - `df['columnx'] == 'xyz'` -> Call a column and test against a condition (this returns a column of true/false values)
# - `df[...]` -> Wrap the test with the main dataframe to filter to rows where our condition is true.

# %% [markdown]
# To help searching for items without scrolling back to top

# %%
# If we add '|' to the string, it acts as an OR operator, so we can search for multiple keywords at once.
items_df_current[items_df_current['description'].str.contains('bread', case=False)]
# Out:
#      item_id                     description  date_quote_s  date_quote_e  \
# 3     210106     SIX BREAD ROLLS-WHITE/BROWN        198802        202510
# 11    210114            CHILLED GARLIC BREAD        201002        202510
# 13    210116   GLUTEN FREE BREAD LF 300-550G        202402        202510
# 126   211211  FROZEN BREAD/BAT FISH 400-550G        201002        202510
#
#      n_obs
# 3    67469
# 11   41672
# 13    2205
# 126  40004

# %%
items_df_current[items_df_current['description'].str.contains('frozen', case=False)]
# Out:
#      item_id                     description  date_quote_s  date_quote_e  \
# 43    210320    WHOLE SPONGE CAKE NOT FROZEN        200002        202510
# 53    210414    FROZEN BEEFBURGERS PACK OF 4        199202        202510
# 118   211106            FROZEN PRAWNS PER KG        200402        202510
# 125   211210     FROZEN FISH FINGERS 8-12 PK        200402        202510
# 126   211211  FROZEN BREAD/BAT FISH 400-550G        201002        202510
# 246   212405         FROZEN CHIPS 900G-1.5KG        199202        202510
# 288   212609     FROZEN GARDEN PEAS 800G-1KG        199402        202510
# 291   212612   FROZEN PRE-PREPARED VEGTABLES        202102        202510
# 332   212809             BERRIES FROZEN PACK        202302        202510
# 367   212943        YORKSHIRE PUDDING FROZEN        202202        202510
#
#      n_obs
# 43   39549
# 53   50005
# 118  36945
# 125  53776
# 126  40004
# 246  89845
# 288  61860
# 291  17685
# 332  10118
# 367   9752

# %%
items_df_current[items_df_current['description'].str.contains('chicken', case=False)]
# Out:
#      item_id                    description  date_quote_s  date_quote_e  \
# 77    210905  FRESH/CHILLED CHICKEN  PER KG        198903        202510
# 82    210910  FRESH BONELESS CHICKEN BREAST        200302        202510
# 103   211019  FROZ CHICKEN NUGGETS 220-600G        200502        202510
# 109   211026   CHICKEN KIEV 2 PACK 240-325G        201502        202510
# 427   220326       TAKEAWAY CHICKEN & CHIPS        201202        202510
#
#       n_obs
# 77   105251
# 82    65366
# 103   28024
# 109   26070
# 427   19909

# %%
items_df_current[items_df_current['description'].str.contains('beef', case=False)]
# Out:
#     item_id                     description  date_quote_s  date_quote_e  \
# 48   210403  HOME KILLED BEEF-LEAN MINCE KG        198802        202510
# 50   210406  HOME KLD BEEF-RUMP/POPES STEAK        198802        202510
# 53   210414    FROZEN BEEFBURGERS PACK OF 4        199202        202510
# 55   210416      BEEF ROASTING JOINT PER KG        202002        202510
#
#      n_obs
# 48  121745
# 50  117178
# 53   50005
# 55   12885

# %%
# 210106 Bread, 211210 frozen fish, 212405 frozen chips, 210905 Fresh chicken, 210406 Beef Steak

# %%
# 1. Filter prices based on TWO item IDs. 
# (we can use `.isin()` to filter by checking against a multiple values in list)
takeaway_prices = prices_df[prices_df['item_id'].isin([210106, 211210, 212405, 210905, 210403])].copy()

# 2. Group by date and item_id, calculate mean price, store in new dataframe
takeaway_price_stats = takeaway_prices.groupby(['date', 'item_id']).agg({'price': 'mean'}).reset_index()

# We have columns 'date', 'item_id', 'price'
takeaway_price_stats
# Out:
#            date  item_id      price
# 0    1988-02-01   210106   0.477151
# 1    1988-02-01   210403   2.806472
# 2    1988-03-01   210106   0.469620
# 3    1988-03-01   210403   2.891031
# 4    1988-04-01   210106   0.474181
# ...         ...      ...        ...
# 2003 2025-10-01   210106   1.272340
# 2004 2025-10-01   210403  11.601636
# 2005 2025-10-01   210905   4.610573
# 2006 2025-10-01   211210   3.027621
# 2007 2025-10-01   212405   2.792240
#
# [2008 rows x 3 columns]

# %% [markdown]
# **Visualise**

# %%
alt.Chart(takeaway_price_stats).mark_line().encode(
    x=alt.X("date:T"),
    y=alt.Y("price"),
    color=alt.Color("item_id:N")
).properties(
    width=400,
    height=250,
    title=alt.TitleParams(
        text="Takeaway Items: Price History",
        subtitle=["Mean average price", "Source: ONS microdata via Davies (2021)"],
        anchor="start",
        frame='group'
    )
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <br>
#
# **How do we add replace our item_id with the descriptions?**
# We could manually set the values in the chart spec, but better to either:
# 1. Merge the `description` from items_df into our filtered prices
# 2. Set our own values for each item_id. And add new column mapping item_id to some description we've set.

# %%
# Option 1. Call `.merge` method on our filtered dataframe to add descriptions. 
#  match `on` item_id column in each dataframe. `how='left'` to keep all rows in takeaway_price_stats.
takeaway_price_stats.merge(items_df[['item_id', 'description']], on='item_id', how='left')
# Out:
#            date  item_id      price                     description
# 0    1988-02-01   210106   0.477151     SIX BREAD ROLLS-WHITE/BROWN
# 1    1988-02-01   210403   2.806472  HOME KILLED BEEF-LEAN MINCE KG
# 2    1988-03-01   210106   0.469620     SIX BREAD ROLLS-WHITE/BROWN
# 3    1988-03-01   210403   2.891031  HOME KILLED BEEF-LEAN MINCE KG
# 4    1988-04-01   210106   0.474181     SIX BREAD ROLLS-WHITE/BROWN
# ...         ...      ...        ...                             ...
# 2003 2025-10-01   210106   1.272340     SIX BREAD ROLLS-WHITE/BROWN
# 2004 2025-10-01   210403  11.601636  HOME KILLED BEEF-LEAN MINCE KG
# 2005 2025-10-01   210905   4.610573   FRESH/CHILLED CHICKEN  PER KG
# 2006 2025-10-01   211210   3.027621     FROZEN FISH FINGERS 8-12 PK
# 2007 2025-10-01   212405   2.792240         FROZEN CHIPS 900G-1.5KG
#
# [2008 rows x 4 columns]

# %%
# Option 2. Define our own mapping of item_id to description, and add new column.
item_labels = {210106: 'Bread', 211210: 'frozen fish', 212405: 'frozen chips', 210905: 'Fresh chicken', 210403: 'Beef'} 

# Use the `.map()` method to create new column 'label' based on mapping dictionary. It finds the value in the dictionary for each item_id.
takeaway_price_stats['label'] = takeaway_price_stats['item_id'].map(item_labels)
takeaway_price_stats
# Out:
#            date  item_id      price          label
# 0    1988-02-01   210106   0.477151          Bread
# 1    1988-02-01   210403   2.806472           Beef
# 2    1988-03-01   210106   0.469620          Bread
# 3    1988-03-01   210403   2.891031           Beef
# 4    1988-04-01   210106   0.474181          Bread
# ...         ...      ...        ...            ...
# 2003 2025-10-01   210106   1.272340          Bread
# 2004 2025-10-01   210403  11.601636           Beef
# 2005 2025-10-01   210905   4.610573  Fresh chicken
# 2006 2025-10-01   211210   3.027621    frozen fish
# 2007 2025-10-01   212405   2.792240   frozen chips
#
# [2008 rows x 4 columns]

# %% [markdown]
# <br>
#
# Visualise again, encoding colour on our new label / description column

# %%
alt.Chart(takeaway_price_stats).mark_line().encode(
    x=alt.X("date:T"),
    y=alt.Y("price"),
    color=alt.Color("label:N")
).properties(
    width=400,
    height=250,
    title=alt.TitleParams(
        text="Food products I usually buy",
        subtitle=["Mean average monthly price", "Source: ONS microdata via Davies (2021)"],
        anchor="start",
        frame='group'
    )
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
takeaway_price_stats_2005 = takeaway_price_stats[
    takeaway_price_stats["date"] >= "2005-01-01"
]

# %%
takeaway_price_stats_2005["date"] = pd.to_datetime(takeaway_price_stats_2005["date"])
# Out:
# /var/folders/p7/_ml_f8590cg3dmhph8rb7ydc0000gn/T/ipykernel_36495/3206033494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   takeaway_price_stats_2005["date"] = pd.to_datetime(takeaway_price_stats_2005["date"])

# %%
lines = alt.Chart(takeaway_price_stats_2005).mark_line().encode(
    x=alt.X("date:T")
        .title('')
        .axis(grid=False),
    y=alt.Y("price:Q")
        .title('')
        .axis(labelExpr="'£' + datum.value"),
    color=alt.Color("label:N")
        .legend(None)
        .scale(
            range=[
                '#70B0FA',
                '#F54927',
                '#2FBF71',
                '#F2C94C',
                '#9B51E0'
            ]
        )
).properties(
    width=400,
    height=250,
    title=alt.TitleParams(
        text="Food products I usually buy",
        subtitle=[
            "Mean average monthly price",
            "Source: ONS microdata via Davies (2021)"
        ],
        anchor="start",
        frame='group'
    )
)

text = lines.mark_text(
    align='left',
    dx=5,
    fontSize=12,
    fontWeight='bold'
).encode(
    x=alt.X("date:T").aggregate('max'),
    y=alt.Y("price:Q").aggregate({'argmax': 'date'}),
    text=alt.Text('label:N')
)

chart = (lines + text).configure_view(
    strokeWidth=0
)

chart
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)

# %%
#Exporting CSV to do the chart in vegalite 

takeaway_price_stats_2005.to_csv('takeaway_price_stats_2005.csv', index=False)

# %% [markdown]
# ### Chart 2

# %%
items_df_current[items_df_current['description'].str.contains('women', case=False)]
# Out:
#       item_id                     description  date_quote_s  date_quote_e  \
# 862    510206           WOMENS BLOUSE/SHIRT 1        198802        202510
# 864    510208           WOMEN'S FORMAL JACKET        198802        202510
# 868    510212                  WOMEN'S JUMPER        198802        202510
# 871    510215      WOMENS BASIC PLAIN T-SHIRT        198802        202510
# 873    510219     WOMEN'S CASUAL OUTER JACKET        199702        202510
# 877    510223  WOMEN'S LONG SLV TOP-NT BLOUSE        199702        202510
# 887    510233                WOMEN'S CARDIGAN        199902        202510
# 889    510235         WOMEN'S TROUSERS-CASUAL        200102        202510
# 890    510236         WOMEN'S TROUSERS-FORMAL        200102        202510
# 891    510237           WOMEN'S SKIRT: CASUAL        200102        202510
# 892    510238      WOMEN'S SKIRT: WORK/FORMAL        200102        202510
# 898    510244        WOMEN'S VEST/STRAPPY TOP        200102        202510
# 899    510245     WOMENS DRESS -CASUAL/FORMAL        200202        202510
# 900    510246  WOMENS SHORT SLEEVE SPORTS TOP        200202        202510
# 901    510248        WOMEN'S JEANS- OWN BRAND        200402        202510
# 902    510249          WOMEN'S JEANS- BRANDED        200402        202510
# 903    510250  WOMEN'S COAT - SEE HELP SCREEN        200602        202510
# 906    510254        WOMENS SPORTSWEAR SHORTS        200602        202510
# 907    510256      WOMEN'S SHOWERPROOF JACKET        200602        202510
# 908    510257         WOMENS BLOUSE / SHIRT 2        201102        202510
# 909    510258     WOMENS LEGGINGS FULL LENGTH        201602        202510
# 910    510259  WOMENS SHORT SLEEVE FORMAL TOP        201602        202510
# 911    510260        WOMENS EXERCISE LEGGINGS        201802        202510
# 912    510261              WOMEN'S SWEATSHIRT        199402        202510
# 972    510405      WOMEN'S NIGHTDRESS/PYJAMAS        198802        202510
# 973    510406                   WOMEN'S PANTS        198802        202510
# 975    510409                WOMEN'S SWIMWEAR        199403        202510
# 979    510415                  WOMEN'S TIGHTS        198802        202510
# 997    510440              WOMENS SOCK 1 PAIR        202402        202510
# 1017   510506                 WOMEN'S SANDALS        198802        202510
# 1026   510517          WOMEN'S TRAINING SHOES        199702        202510
# 1039   510530  WOMEN'S SHOES-FLAT MAX 1" HEEL        200402        202510
# 1042   510533                     WOMENS SHOE        201102        202510
# 1109   520234  PERFUME/FRAGRANCE MEN OR WOMEN        200102        202510
# 1111   520236  WOMENS HAIR COLOURANT 60-140ML        200202        202510
# 1133   520303  WOMEN'S HRDRESSING-CUT/BLOWDRY        198802        202510
# 1136   520311             WOMENS HIGHLIGHTING        199402        202510
#
#        n_obs
# 862   123005
# 864   121087
# 868   123638
# 871   102756
# 873    92647
# 877    92645
# 887    89806
# 889    88024
# 890    89872
# 891    83349
# 892    83232
# 898    78616
# 899    77350
# 900    52118
# 901    69619
# 902    40637
# 903    38604
# 906    40471
# 907    34933
# 908    59597
# 909    36758
# 910    37302
# 911    22654
# 912    31752
# 972   120509
# 973   131905
# 975    59138
# 979   126017
# 997     6349
# 1017  102958
# 1026   49620
# 1039   78509
# 1042   52700
# 1109   47679
# 1111   35164
# 1133  124203
# 1136   99991

# %%
items_df_current[items_df_current['description'].str.contains('jacket', case=False)]
# Out:
#      item_id                  description  date_quote_s  date_quote_e   n_obs
# 820   510104             MENS JACKET/COAT        198802        202510  122442
# 848   510134    MENS FORMAL JACKET/BLAZER        202202        202510   13015
# 864   510208        WOMEN'S FORMAL JACKET        198802        202510  121087
# 873   510219  WOMEN'S CASUAL OUTER JACKET        199702        202510   92647
# 907   510256   WOMEN'S SHOWERPROOF JACKET        200602        202510   34933
# 959   510347    GIRLS JACKET (5-13 YEARS)        201102        202510   55706

# %%
items_df_current[items_df_current['description'].str.contains('jumper', case=False)]
# Out:
#      item_id                    description  date_quote_s  date_quote_e  \
# 824   510108           MEN'S JUMPER-KNITTED        198802        202510
# 834   510120     MEN'S JUMPER OR SWEATSHIRT        199702        202510
# 868   510212                 WOMEN'S JUMPER        198802        202510
# 962   510350  BOY'S JUMPER/SWTSHRT/CARDIGAN        202102        202510
#
#       n_obs
# 824  124502
# 834   98703
# 868  123638
# 962   19484

# %%
items_df_current[items_df_current['description'].str.contains('trousers', case=False)]
# Out:
#      item_id                     description  date_quote_s  date_quote_e  \
# 831   510117  MEN'S FORMAL RDY-MADE TROUSERS        199702        202510
# 832   510118           MEN'S CASUAL TROUSERS        199702        202510
# 889   510235         WOMEN'S TROUSERS-CASUAL        200102        202510
# 890   510236         WOMEN'S TROUSERS-FORMAL        200102        202510
# 940   510324   TROUSERS  FOR SCHOOL 5-13 YRS        200202        202510
# 956   510344   GIRLS TROUSERS NOT DENIM 5-13        200602        202510
# 963   510351     INFANT'S TROUSERS 0-2 YEARS        202102        202510
#
#       n_obs
# 831  104919
# 832  102736
# 889   88024
# 890   89872
# 940   77162
# 956   66471
# 963   15709

# %%
items_df_current[items_df_current['description'].str.contains('sock', case=False)]
# Out:
#      item_id                description  date_quote_s  date_quote_e   n_obs
# 978   510413          MENS SOCKS 1 PAIR        198802        202510  133027
# 995   510438  CHILDS SOCKS ONE PAIR UK9        202202        202510   14689
# 997   510440         WOMENS SOCK 1 PAIR        202402        202510    6349

# %%
gender_prices = prices_df[prices_df['item_id'].isin([510104, 510208, 510108, 510212, 510118, 510235, 510120, 510261])].copy()

# 2. Group by date and item_id, calculate mean price, store in new dataframe
gender_prices_stat = gender_prices.groupby(['date', 'item_id']).agg({'price': 'mean'}).reset_index()

# We have columns 'date', 'item_id', 'price'
gender_prices_stat
# Out:
#            date  item_id      price
# 0    1988-02-01   510104  33.625988
# 1    1988-02-01   510108  16.794111
# 2    1988-02-01   510208  39.951195
# 3    1988-02-01   510212  15.182670
# 4    1988-03-01   510104  33.470524
# ...         ...      ...        ...
# 2898 2025-10-01   510120  43.324360
# 2899 2025-10-01   510208  66.601006
# 2900 2025-10-01   510212  37.775963
# 2901 2025-10-01   510235  32.214405
# 2902 2025-10-01   510261  32.282207
#
# [2903 rows x 3 columns]

# %%
gender_prices_stat.merge(items_df[['item_id', 'description']], on='item_id', how='left')
# Out:
#            date  item_id      price                 description
# 0    1988-02-01   510104  33.625988            MENS JACKET/COAT
# 1    1988-02-01   510108  16.794111        MEN'S JUMPER-KNITTED
# 2    1988-02-01   510208  39.951195       WOMEN'S FORMAL JACKET
# 3    1988-02-01   510212  15.182670              WOMEN'S JUMPER
# 4    1988-03-01   510104  33.470524            MENS JACKET/COAT
# ...         ...      ...        ...                         ...
# 2898 2025-10-01   510120  43.324360  MEN'S JUMPER OR SWEATSHIRT
# 2899 2025-10-01   510208  66.601006       WOMEN'S FORMAL JACKET
# 2900 2025-10-01   510212  37.775963              WOMEN'S JUMPER
# 2901 2025-10-01   510235  32.214405     WOMEN'S TROUSERS-CASUAL
# 2902 2025-10-01   510261  32.282207          WOMEN'S SWEATSHIRT
#
# [2903 rows x 4 columns]

# %%
# Option 2. Define our own mapping of item_id to description, and add new column.
gender_item_labels = {510104: 'Men jacket', 510208: 'Women jacket', 510108: 'Men jumper', 510212: 'Women jumper', 510118: 'Men trousers', 510235: 'Women trousers', 510120: 'Men sweatshirt', 510261: 'Women sweatshirt'} 

# Use the `.map()` method to create new column 'label' based on mapping dictionary. It finds the value in the dictionary for each item_id.
gender_prices_stat['label'] = gender_prices_stat['item_id'].map(gender_item_labels)
gender_prices_stat
# Out:
#            date  item_id      price             label gender     product
# 0    1988-02-01   510104  33.625988        Men jacket    Men      Jacket
# 1    1988-02-01   510108  16.794111        Men jumper    Men      Jumper
# 2    1988-02-01   510208  39.951195      Women jacket  Women      Jacket
# 3    1988-02-01   510212  15.182670      Women jumper  Women      Jumper
# 4    1988-03-01   510104  33.470524        Men jacket    Men      Jacket
# ...         ...      ...        ...               ...    ...         ...
# 2898 2025-10-01   510120  43.324360    Men sweatshirt    Men  Sweatshirt
# 2899 2025-10-01   510208  66.601006      Women jacket  Women      Jacket
# 2900 2025-10-01   510212  37.775963      Women jumper  Women      Jumper
# 2901 2025-10-01   510235  32.214405    Women trousers  Women    Trousers
# 2902 2025-10-01   510261  32.282207  Women sweatshirt  Women  Sweatshirt
#
# [2903 rows x 6 columns]

# %%
# Option 2. Define our own mapping of item_id to description, and add new column.
gender_item = {510104: 'Men', 510208: 'Women', 510108: 'Men', 510212: 'Women', 510118: 'Men', 510235: 'Women', 510120: 'Men', 510261: 'Women'} 

# Use the `.map()` method to create new column 'label' based on mapping dictionary. It finds the value in the dictionary for each item_id.
gender_prices_stat['gender'] = gender_prices_stat['item_id'].map(gender_item)
gender_prices_stat
# Out:
#            date  item_id      price              label gender
# 0    1988-02-01   510104  33.625988         Men jacket    Men
# 1    1988-02-01   510108  16.794111         Men jumper    Men
# 2    1988-02-01   510208  39.951195       Women jacket  Women
# 3    1988-02-01   510212  15.182670       Women jumper  Women
# 4    1988-03-01   510104  33.470524         Men jacket    Men
# ...         ...      ...        ...                ...    ...
# 2898 2025-10-01   510120  43.324360     Men sweatshirt    Men
# 2899 2025-10-01   510208  66.601006       Women jacket  Women
# 2900 2025-10-01   510212  37.775963       Women jumper  Women
# 2901 2025-10-01   510235  32.214405     Women trousers  Women
# 2902 2025-10-01   510261  32.282207  Women sweat shirt  Women
#
# [2903 rows x 5 columns]

# %%
# Option 2. Define our own mapping of item_id to description, and add new column.
product_item = {510104: 'Jacket', 510208: 'Jacket', 510108: 'Jumper', 510212: 'Jumper', 510118: 'Trousers', 510235: 'Trousers', 510120: 'Sweatshirt', 510261: 'Sweatshirt'} 

# Use the `.map()` method to create new column 'label' based on mapping dictionary. It finds the value in the dictionary for each item_id.
gender_prices_stat['product'] = gender_prices_stat['item_id'].map(product_item)
gender_prices_stat
# Out:
#            date  item_id      price             label gender     product
# 0    1988-02-01   510104  33.625988        Men jacket    Men      Jacket
# 1    1988-02-01   510108  16.794111        Men jumper    Men      Jumper
# 2    1988-02-01   510208  39.951195      Women jacket  Women      Jacket
# 3    1988-02-01   510212  15.182670      Women jumper  Women      Jumper
# 4    1988-03-01   510104  33.470524        Men jacket    Men      Jacket
# ...         ...      ...        ...               ...    ...         ...
# 2898 2025-10-01   510120  43.324360    Men sweatshirt    Men  Sweatshirt
# 2899 2025-10-01   510208  66.601006      Women jacket  Women      Jacket
# 2900 2025-10-01   510212  37.775963      Women jumper  Women      Jumper
# 2901 2025-10-01   510235  32.214405    Women trousers  Women    Trousers
# 2902 2025-10-01   510261  32.282207  Women sweatshirt  Women  Sweatshirt
#
# [2903 rows x 6 columns]

# %%
# Option 2. Define our own mapping of item_id to description, and add new column.
description_item = {510104: "MENS JACKET/COAT", 510208: "WOMEN'S FORMAL JACKET", 510108: "MEN'S JUMPER-KNITTED", 510212: "WOMEN'S JUMPER", 510118: "MEN'S CASUAL TROUSERS", 510235: "WOMEN'S TROUSERS-CASUAL", 510120: "MEN'S JUMPER OR SWEATSHIRT", 510261: "WOMEN'S SWEATSHIRT"} 

# Use the `.map()` method to create new column 'label' based on mapping dictionary. It finds the value in the dictionary for each item_id.
gender_prices_stat['description'] = gender_prices_stat['item_id'].map(description_item)
gender_prices_stat
# Out:
#            date  item_id      price             label gender     product  \
# 0    1988-02-01   510104  33.625988        Men jacket    Men      Jacket
# 1    1988-02-01   510108  16.794111        Men jumper    Men      Jumper
# 2    1988-02-01   510208  39.951195      Women jacket  Women      Jacket
# 3    1988-02-01   510212  15.182670      Women jumper  Women      Jumper
# 4    1988-03-01   510104  33.470524        Men jacket    Men      Jacket
# ...         ...      ...        ...               ...    ...         ...
# 2898 2025-10-01   510120  43.324360    Men sweatshirt    Men  Sweatshirt
# 2899 2025-10-01   510208  66.601006      Women jacket  Women      Jacket
# 2900 2025-10-01   510212  37.775963      Women jumper  Women      Jumper
# 2901 2025-10-01   510235  32.214405    Women trousers  Women    Trousers
# 2902 2025-10-01   510261  32.282207  Women sweatshirt  Women  Sweatshirt
#
#                      description
# 0               MENS JACKET/COAT
# 1           MEN'S JUMPER-KNITTED
# 2          WOMEN'S FORMAL JACKET
# 3                 WOMEN'S JUMPER
# 4               MENS JACKET/COAT
# ...                          ...
# 2898  MEN'S JUMPER OR SWEATSHIRT
# 2899       WOMEN'S FORMAL JACKET
# 2900              WOMEN'S JUMPER
# 2901     WOMEN'S TROUSERS-CASUAL
# 2902          WOMEN'S SWEATSHIRT
#
# [2903 rows x 7 columns]

# %%
alt.Chart(gender_prices_stat).mark_line().encode(
    x=alt.X("date:T"),
    y=alt.Y("price"),
    color=alt.Color("label:N")
).properties(
    width=400,
    height=250,
    title=alt.TitleParams(
        text="Food products I usually buy",
        subtitle=["Mean average monthly price", "Source: ONS microdata via Davies (2021)"],
        anchor="start",
        frame='group'
    )
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
gender_prices_stat_2000 = gender_prices_stat[
    gender_prices_stat["date"] >= "2000-01-01"
]

# %%
gender_prices_stat_2000["date"] = pd.to_datetime(gender_prices_stat_2000["date"])
# Out:
# /var/folders/p7/_ml_f8590cg3dmhph8rb7ydc0000gn/T/ipykernel_36495/3069960139.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_prices_stat_2000["date"] = pd.to_datetime(gender_prices_stat_2000["date"])

# %%
#Exporting CSV to do the chart in vegalite 

gender_prices_stat_2000.to_csv('gender_prices.csv', index=False)

# %%
gender_prices_stat_2000
# Out:
#            date  item_id      price             label gender     product  \
# 689  2000-01-01   510104  53.617294        Men jacket    Men      Jacket
# 690  2000-01-01   510108  26.001524        Men jumper    Men      Jumper
# 691  2000-01-01   510118  27.944092      Men trousers    Men    Trousers
# 692  2000-01-01   510120  25.273527    Men sweatshirt    Men  Sweatshirt
# 693  2000-01-01   510208  57.207096      Women jacket  Women      Jacket
# ...         ...      ...        ...               ...    ...         ...
# 2898 2025-10-01   510120  43.324360    Men sweatshirt    Men  Sweatshirt
# 2899 2025-10-01   510208  66.601006      Women jacket  Women      Jacket
# 2900 2025-10-01   510212  37.775963      Women jumper  Women      Jumper
# 2901 2025-10-01   510235  32.214405    Women trousers  Women    Trousers
# 2902 2025-10-01   510261  32.282207  Women sweatshirt  Women  Sweatshirt
#
#                      description
# 689             MENS JACKET/COAT
# 690         MEN'S JUMPER-KNITTED
# 691        MEN'S CASUAL TROUSERS
# 692   MEN'S JUMPER OR SWEATSHIRT
# 693        WOMEN'S FORMAL JACKET
# ...                          ...
# 2898  MEN'S JUMPER OR SWEATSHIRT
# 2899       WOMEN'S FORMAL JACKET
# 2900              WOMEN'S JUMPER
# 2901     WOMEN'S TROUSERS-CASUAL
# 2902          WOMEN'S SWEATSHIRT
#
# [2214 rows x 7 columns]
